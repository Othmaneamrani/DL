# %% [markdown]
# # CNN classification based on fruits dataset

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Dataset

# %%
img_height,img_width=32,32
batchSize=20 #ch7al mn image ayhez
train_dataset=tf.keras.utils.image_dataset_from_directory("fruits/train",image_size=(img_height,img_width),batch_size=batchSize)

validation_dataset=tf.keras.utils.image_dataset_from_directory("fruits/validation",image_size=(img_height,img_width),batch_size=batchSize)

test_dataset=tf.keras.utils.image_dataset_from_directory("fruits/test",image_size=(img_height,img_width),batch_size=batchSize)
# Out:
# Found 460 files belonging to 3 classes.
# Found 66 files belonging to 3 classes.
# Found 130 files belonging to 3 classes.

# %% [markdown]
# ## Step 2: visualisation des donnees

# %%
class_names=['apple','banana','orange']
plt.figure(figsize=(5,5))
for img,label in train_dataset.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(img[i].numpy().astype("uint8"))
        plt.title(class_names[label[i]])
        plt.axis("off")
    plt.show()

# %% [markdown]
# ## Step 3: Creation du modele

# %%
modelCNN=tf.keras.Sequential(
    [
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(32,3,activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(32,3,activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(32,3,activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128,activation='relu'),
        tf.keras.layers.Dense(3,activation='softmax'),
    ]
)

# %% [markdown]
# ## Step4: parametrages du modele

# %%
modelCNN.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Step 5: Training

# %%
modelCNN.fit(train_dataset,validation_data=validation_dataset,epochs=10)
# Out:
# Epoch 1/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.4480 - loss: 1.0367 - val_accuracy: 0.7273 - val_loss: 0.7756
# Epoch 2/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7049 - loss: 0.6562 - val_accuracy: 0.6970 - val_loss: 0.6537
# Epoch 3/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8409 - loss: 0.3749 - val_accuracy: 0.8636 - val_loss: 0.3628
# Epoch 4/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9065 - loss: 0.2788 - val_accuracy: 0.9091 - val_loss: 0.2354
# Epoch 5/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9350 - loss: 0.1940 - val_accuracy: 0.8636 - val_loss: 0.4152
# Epoch 6/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9523 - loss: 0.1740 - val_accuracy: 0.9091 - val_loss: 0.3499
# Epoch 7/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9574 - loss: 0.1507 - val_accuracy: 0.9394 - val_loss: 0.1508
# Epoch 8/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9479 - loss: 0.1448 - val_accuracy: 0.9394 - val_loss: 0.1355
# Epoch 9/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9761 - loss: 0.1170 - val_accuracy: 0.9242 - val_loss: 0.2010
# Epoch 10/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9673 - loss: 0.0798 - val_accuracy: 0.9091 - val_loss: 0.1996

# %%
modelCNN.evaluate(test_dataset,verbose=2)
# Out:
# 7/7 - 0s - 45ms/step - accuracy: 0.9462 - loss: 0.1960
# [0.19603191316127777, 0.9461538195610046]

# %%
modelCNN.save("fruits_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
